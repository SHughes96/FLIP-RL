# %%
import gym
import stable_baselines3
from stable_baselines3 import PPO, A2C
import os

models_dir = "models/PPO_testing"
logdir = "logs"

# %%
if not os.path.exists(models_dir):
    os.makedirs(models_dir)
if not os.path.exists(models_dir):
    os.makedirs(logdir)

# %%
env = gym.make("LunarLander-v2")
env.reset()
# Out:
# (array([-0.00453882,  1.4068115 , -0.45975026, -0.18261732,  0.00526616,
#          0.1041402 ,  0.        ,  0.        ], dtype=float32),
#  {})

# %%
#model = PPO("MlpPolicy", env, verbose=1, tensorboard_log=logdir)

model_path = '/Users/slh/Documents/Projects/personal/ML/Delta_RL/Delta_RL/models/PPO_testing/10000.zip'
model = PPO.load(model_path, env=env)

TIMESTEPS = 10000
# for i in range(1, 30):
#     print(i)
#     model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name="PPO")
#     model.save(f"{models_dir}/{TIMESTEPS*i}")

episodes = 10

for ep in range(episodes):
    obs = env.reset()
    done = False
    while not done:
        env.render()
        action, _ = model.predict(obs)
        #output = env.step(env.action_space.sample())
        obs, reward, done, info = env.step(action)
        #print(reward)


env.close()
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 19
#      17 while not done:
#      18     env.render()
# ---> 19     action, _ = model.predict(obs)
#      20     #output = env.step(env.action_space.sample())
#      21     obs, reward, done, info = env.step(action)
#
# File ~/anaconda3/envs/RL_env/lib/python3.10/site-packages/stable_baselines3/common/base_class.py:553, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     533 def predict(
#     534     self,
#     535     observation: Union[np.ndarray, Dict[str, np.ndarray]],
#    (...)
#     538     deterministic: bool = False,
#     539 ) -> Tuple[np.ndarray, Optional[Tuple[np.ndarray, ...]]]:
#     540     """
#     541     Get the policy action from an observation (and optional hidden state).
#     542     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)
#     551         (used in recurrent policies)
#     552     """
# --> 553     return self.policy.predict(observation, state, episode_start, deterministic)
#
# File ~/anaconda3/envs/RL_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:355, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     352 # Check for common mistake that the user does not mix Gym/VecEnv API
#     353 # Tuple obs are not supported by SB3, so we can safely do that check
#     354 if isinstance(observation, tuple) and len(observation) == 2 and isinstance(observation[1], dict):
# --> 355     raise ValueError(
#     356         "You have passed a tuple to the predict() function instead of a Numpy array or a Dict. "
#     357         "You are probably mixing Gym API with SB3 VecEnv API: `obs, info = env.reset()` (Gym) "
#     358         "vs `obs = vec_env.reset()` (SB3 VecEnv). "
#     359         "See related issue https://github.com/DLR-RM/stable-baselines3/issues/1694 "
#     360         "and documentation for more information: https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecenv-api-vs-gym-api"
#     361     )
#     363 obs_tensor, vectorized_env = self.obs_to_tensor(observation)
#     365 with th.no_grad():
#
# ValueError: You have passed a tuple to the predict() function instead of a Numpy array or a Dict. You are probably mixing Gym API with SB3 VecEnv API: `obs, info = env.reset()` (Gym) vs `obs = vec_env.reset()` (SB3 VecEnv). See related issue https://github.com/DLR-RM/stable-baselines3/issues/1694 and documentation for more information: https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecenv-api-vs-gym-api

# %%
# Out:
# -0.8134199750505786
# -1.319654875126605
# -0.7878177828085882
# -2.0084868269679235
# -1.7010438858012151
# 0.04011030021013198
# -2.1002079638295457
# -1.0317529000796242
# -2.240895614284908
# -1.4077170611544603
# -2.5795365621379163
# -0.5607966035043137
# -0.04666200255044714
# 0.015925712001690046
# 0.39929807354701663
# -0.2235384080646156
# 0.30452537576488337
# -0.4232464526349986
# 0.8026157722417906
# 0.4427778728476153
# 1.9120819322915394
# -1.6544806976592088
# -0.5830527375590748
# -1.5469573941428212
# -1.936781878168971
# -2.028458273413405
# -1.064212260634406
# -1.0640457436149973
# -0.1685800576286624
# 0.06726405539447569
# -0.6028431027391037
# -2.034737954528167
# 1.9053352550984755
# -0.07522972326486752
# -2.0083796739015427
# 0.04353140702394967
# -0.8777823219323295
# -2.1306818262434306
# -1.0977274008724862
# -0.18360140175528158
# -0.9099757800418615
# 2.056078623729303
# 0.18989529635308713
# 0.4464133417809933
# 1.1273534870634137
# -0.8041991229459313
# 0.13486374300615125
# 0.25326985821179165
# 0.27147900929352997
# -0.439231880454912
# -1.4394687637338268
# 0.1259039011207517
# -0.4903416376900793
# -0.43995215547106453
# -0.47865931847516663
# -0.4937924472536679
# 0.4733840102378235
# 0.7472738782958868
# -0.13005890343231385
# -0.15773628079588775
# 0.5014774104652713
# -0.07853999879819185
# -0.12130858107764197
# 0.6817795081167628
# -1.0788950350737696
# -0.32296215900430525
# -0.3952359664003495
# 3.1449422302966754
# -1.2691043498525392
# -0.8289624584880642
# 2.5025052295946297
# -1.0808530600089625
# 0.44360921809613957
# -1.2572028348326967
# -2.2132759647746796
# -2.43613640061116
# -1.3603519874229721
# 1.7743077180494822
# -3.1385149376467028
# -3.5481015328459464
# -0.575551228821314
# -2.237823392132127
# -2.3705383770849253
# -0.8942188735155014
# -3.1563464121219624
# -3.3093718388943785
# 0.05577614663230862
# -4.638032397461273
# -0.491252401393001
# 5.267180251987527
# 9.480269429985707
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# -100
# /Users/slh/anaconda3/envs/RL_env/lib/python3.10/site-packages/gym/envs/box2d/lunar_lander.py:604: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym("LunarLander-v2", render_mode="rgb_array")
#   gym.logger.warn(
